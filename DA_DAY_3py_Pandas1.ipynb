# %% [markdown]
# pandas-
# -used for data manipulations
# -creates dataframes from excel_csv,txt,DBs
# -dataframes (rowss and columns readable by python)
# -data cleaning by dropping or replacing with mean
# -visualize the data

# %%
import pandas as pd

# %%
names=["sai","kumar","vijay","soma"]
index=[40,42,44,46]
seri=pd.Series(names,index)
print(seri)
# Out:
# 40      sai
# 42    kumar
# 44    vijay
# 46     soma
# dtype: object

# %% [markdown]
# importing files
#
#
# -for csv and txt:read_csv("file path")
#
#
# -for excel:read_excel("file path")

# %%
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")

# %%
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.head(10)
# Out:
#     preg,plas,pres,skin,insu,mass,pedi,age,class
# 0    6,148,72,35,0,33.6,0.627,50,tested_positive
# 1     1,85,66,29,0,26.6,0.351,31,tested_negative
# 2     8,183,64,0,0,23.3,0.672,32,tested_positive
# 3    1,89,66,23,94,28.1,0.167,21,tested_negative
# 4  0,137,40,35,168,43.1,2.288,33,tested_positive
# 5     5,116,74,0,0,25.6,0.201,30,tested_negative
# 6      3,78,50,32,88,31,0.248,26,tested_positive
# 7     10,115,0,0,0,35.3,0.134,29,tested_negative
# 8  2,197,70,45,543,30.5,0.158,53,tested_positive
# 9        8,125,96,0,0,0,0.232,54,tested_positive

# %%
df=pd.read_excel("/content/diabetes.xlsx")

# %%
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
dft=pd.read_csv("/content/grades_withnulls.txt",sep=",")
dft.head()
# Out:
#   Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                      Joe K 9.8 10 9.9 A+ 1
# 1                  Rajesh M 8.9 9.1 9.3 A 1
# 2                    Kissan V 9.9 9.8 10 A 0
# 3                       Mary N 7.7 8 NaN B 0
# 4                    Jeen K 9.8 9.1 9.9 A+ 1

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ")
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B>

# %%
print(dft.shape)
# Out:
# (16, 6)

# %%
print(dft.shape[0])#shows the colums
print(dft.shape[1])#shows the rows
# Out:
# 16
# 6

# %%
print(df.shape)
# Out:
# (768, 1)

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of        preg,plas,pres,skin,insu,mass,pedi,age,class
# 0       6,148,72,35,0,33.6,0.627,50,tested_positive
# 1        1,85,66,29,0,26.6,0.351,31,tested_negative
# 2        8,183,64,0,0,23.3,0.672,32,tested_positive
# 3       1,89,66,23,94,28.1,0.167,21,tested_negative
# 4     0,137,40,35,168,43.1,2.288,33,tested_positive
# ..                                              ...
# 763  10,101,76,48,180,32.9,0.171,63,tested_negative
# 764      2,122,70,27,0,36.8,0.34,27,tested_negative
# 765   5,121,72,23,112,26.2,0.245,30,tested_negative
# 766      1,126,60,0,0,30.1,0.349,47,tested_positive
# 767      1,93,70,31,0,30.4,0.315,23,tested_negative
#
# [768 rows x 1 columns]>

# %%
print(df.columns)
# Out:
# Index(['preg,plas,pres,skin,insu,mass,pedi,age,class'], dtype='object')

# %% [markdown]
# Accesing data
#
# *  loc- accepts column names and index
#
# *   iloc-accepts only index

# %%
dft.describe()
# Out:
#             SEM1       SEM2      SEM3
# count  16.000000  16.000000  16.00000
# mean    8.900000   8.912500   8.86875
# std     1.077652   0.589774   1.10497
# min     7.000000   8.000000   7.00000
# 25%     7.700000   8.750000   8.67500
# 50%     9.350000   9.100000   9.25000
# 75%     9.825000   9.150000   9.45000
# max     9.900000  10.000000   9.90000

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (768, 1)
# 768
# 1

# %%
print(dft[2:5]) #to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5,"Names"])#rows of specified columns
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5])#iloc[row range,column range]=>index
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.iloc[2:5, :3]) #iloc[row range,colum range]
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum()
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum()#to view total nulls
# Out:
# 4

# %%
dfn.dropna() #dropping all the rows with nulls
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc=dfn.dropna()

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# CLeaning with mean

# %%
m=dfn['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
print(dfc2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=dfc2.drop_duplicates()
print(dropped)

# %% [markdown]
# columns

# %%
dfn.rename(columns={"Grades":"GPA"})
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# hi bhayya

# %%
how are you ?
# Out:
#   File "<ipython-input-1-97f2090b888f>", line 1
#     how are you ?
#         ^
# SyntaxError: invalid syntax

# %%
dfc2.rename(columns={"Grades":"GPA"},inplace=True)
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   9.1     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfc2['Avg_score']=(dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3 #df['newcol']=values
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9    A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3     A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0     A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1     B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9    A+       1   9.600000

# %% [markdown]
# PLOTTING with PANDAS

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns
pl=sns.lineplot(x='Names',y='SEM1',data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# load diabates.csv
# create relplot
# with ages as x-axis
# class as columns

# %%
dc=pd.read_csv("/content/diabetcsv.csv")
dc.head()
print(dc)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dc['index']=range(0,768)
print(dc)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      0
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      1
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      2
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      3
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      4
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    763
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    764
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    765
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    766
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    767
#
# [768 rows x 10 columns]

# %%
sns.relplot(
    data=dc,
    x="index",y="age",col="class")

# %% [markdown]
# inbuilt data sets in seaborn
# -tips
# * dowjones
# -FMRI
# -dots
# -health exp
# -to load these data sets use:
# -load_dataset("data_setname")
# -

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time")#hue is create the difference based on a column via colurs

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day")

# %% [markdown]
# #style users different markers different category
#
#
# *   style=different color for different category

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time",palette="colorblind")

# %% [markdown]
# -colour *palates*
# 1.   dark
# 2.   muted
# 3.color blind
# 4.deep
# 5.pal

# %%
sns.relplot(data=fmri,x="signal",y="timepoint")

# %%
sns.catplot(data=tips,y="total_bill",x="time",kind="violin",hue="smoker")

# %% [markdown]
# region=brain location

# %%
sns.relplot(data=fmri,x="event",y="region")

# %%
sns.lmplot(x="size",y="tip",data=tips);

# %% [markdown]
# plot name is linear fit as implot
#
# 1.   plotting the date set
# 2. fitting the line
# 3.prediction

# %% [markdown]
# *  web scraping:
# loading the data from the web sides
# * loading data from websites
#
#
# *   unstructured in HTMl
#
# *convertible into spreadsheets/DB
#
# * major websites have their APIs f
# * extract all the data on particular sites
#
# *   specific data that a user wants
# *   process:
#
# 1.  URL->
# 2.  HTML code->
# 3.ELements (CSS/JS)->
# 4.scrapes the required data
