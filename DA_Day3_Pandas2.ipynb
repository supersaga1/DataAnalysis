# %% [markdown]
# Pandas
# *   used for data manipulation(data cleaning ,organisind data)
# *   creats data frames from excel,csv,txt,DBs
# *   Data frame (rows and columns read by python)
# *   Data cleaning by dropping and replacing with mean
# *   Visuualize the data

# %%
import pandas as pd

# %%
names=["sai","ganesh","chinni","naga","venkata"]
index=[40,42,42,43,45]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 40        sai
# 42     ganesh
# 42     chinni
# 43       naga
# 45    venkata
# dtype: object

# %% [markdown]
# Importing files
# * for csv and txt :read_csv("file path")
# * for excel : read_excel("file path")

# %%
df=pd.read_csv("/content/diabetcsv.csv")

# %%
df.head(10)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
dft=pd.read_csv("/content/grades.txt" ,sep=" ")

# %%
dft.head(20)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")

# %%
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
dft.shape[0]#Get number of rows only
# Out:
# 16

# %%
dft.shape[1]#Get number of columns only
# Out:
# 6

# %%
dft.shape#both rows and columns
# Out:
# (16, 6)

# %%
dft.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade'], dtype='object')

# %% [markdown]
# Accessing data
#
# * loc-accepts column names and index
# *  iloc accepts only index

# %%
dft.describe()
# Out:
#             SEM1       SEM2      SEM3
# count  16.000000  16.000000  16.00000
# mean    8.900000   8.912500   8.86875
# std     1.077652   0.589774   1.10497
# min     7.000000   8.000000   7.00000
# 25%     7.700000   8.750000   8.67500
# 50%     9.350000   9.100000   9.25000
# 75%     9.825000   9.150000   9.45000
# max     9.900000  10.000000   9.90000

# %%
print(dft[2:5])#to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5,"Names"])
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.iloc[2:5, :3])#iloc[row range, column range] =>index
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(10)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False
# 7  False     False  False  False  False  False   False
# 8  False     False   True  False  False  False   False
# 9  False     False   True  False  False  False   False

# %%
dfn.isnull().sum()#to see how many nulls per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum()# to view total nulls
# Out:
# 4

# %%
dfc=dfn.dropna()#dropping all the rows with nulls

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(8)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   8.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   8.0   9.1   9.9    A+       1
# 9   Rajini        M   8.0   9.1   9.3     A       0
# 10   Kiran        V   8.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
m=dfn['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
print(dfc2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
c=dfc2.drop_duplicates()
print(c)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc2.rename(columns={"Grade":"GPA"},inplace=True)#df.rename(columns={old:new})
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   9.1   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
dfc2['Avg_score']=(dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3#df['newcol']=values

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0   A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1   B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9  A+       1   9.600000

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# seaborn

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=dfc2)

# %%
sns.relplot( data=dfc2,x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# Load diabities.csv
#
# *   Create a replot with the index in the x-axis
#
# *   age in x axis

# %%
dc=pd.read_csv("/content/diabetcsv.csv")
print(dc)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dc['index']=(dc.index)#or range(0,768)
print(dc)
sns.relplot( data=dc,x="index",y="age",col="class")
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      0
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      1
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      2
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      3
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      4
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    763
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    764
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    765
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    766
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    767
#
# [768 rows x 10 columns]

# %% [markdown]
# inbuilt data sets in seaborn
#
# * tips
# * dowjones
# * fmri
# * dots
# * healthexp
#
#
# * To load these data sets use
# * load_dataset("data_setname")

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
n=input("enter col ")
m=input("enter style ")
l=input("enter palette ")
sns.relplot( data=tips,x="total_bill",y="tip",hue=n,style=m,palette=l)
# Out:
# enter col smoker
# enter style day
# enter palette dark

# %% [markdown]
# *  hue =different color diff category
# * style=to give diff marker or shape
#
#
# palatee:
#
# *  pastel
#
# *   bright
#
# *   dark
# *  muted
#
#
# *   colorblind
#
#
# *   bee

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head(700)
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot( data=dowjones,x="Date",y="Price",kind='line')

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot( data=fmri,x="signal",y="timepoint")

# %%
healthexp=sns.load_dataset("healthexp")
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.catplot( data=healthexp,x="Country",y="Spending_USD",kind='violin')

# %% [markdown]
# liner regression
#
# plot name is linear fit
#
# implot create a function)
#
# plotting a data set
#
# fitting the line
#
# prediction

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips)

# %% [markdown]
# web scraping:
# *  unstructured in html
# *  covertible into spreadsheets
# *  major websites have their apis for web scrapping
# scrapper:
# * extract all the data on particular sites
# * specific data that a user wants
# process:
# * url->
# * htmlcode->
# * elements(css/js)->
# * scrapes the required data->
# * saves it in required format(csv,xlsx,Json)
#
# Applications
#
# *  Email Marketing
# *  Sentimental Analysis
# *  News Monitoring
# *  Market Research
# *  Price Monitoring

# %%
sns.lmplot(x="size",y="tip",data=tips)
